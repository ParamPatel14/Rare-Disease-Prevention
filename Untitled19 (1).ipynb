# %%
import pandas as pd
import xml.etree.ElementTree as ET
import gzip
import os
import numpy as np

# 1. Simulate a dataset (for immediate development)
def create_simulated_dataset(n_patients=100):
    np.random.seed(42)
    data = {
        'patient_id': range(n_patients),
        'symptoms': [
            'seizures,weak_legs' if i % 2 == 0 else 'rashes,fatigue' for i in range(n_patients)
        ],
        'dna_mutations': [
            'CLN3' if i % 2 == 0 else 'SNRPN' for i in range(n_patients)
        ],
        'disease': [
            'Batten Disease' if i % 2 == 0 else 'Prader-Willi Syndrome' for i in range(n_patients)
        ]
    }
    df = pd.DataFrame(data)
    df.to_csv('simulated_rare_disease_data.csv', index=False)
    return df

# 2. Load Orphanet data (example for XML file)
def load_orphanet_data(file_path):
    if not os.path.exists(file_path):
        print(f"Orphanet file {file_path} not found. Please download from www.orphadata.org.")
        return None
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()
        diseases = []
        for disorder in root.findall('.//Disorder'):
            orpha_code = disorder.find('OrphaCode').text
            name = disorder.find('Name').text
            phenotypes = [hpo.find('Name').text for hpo in disorder.findall('.//HPOTerm')]
            diseases.append({'orpha_code': orpha_code, 'name': name, 'phenotypes': phenotypes})
        return pd.DataFrame(diseases)
    except Exception as e:
        print(f"Error parsing Orphanet file: {e}")
        return None

# 3. Load ClinVar data (example for VCF file)
def load_clinvar_data(file_path):
    if not os.path.exists(file_path):
        print(f"ClinVar file {file_path} not found. Please download from ftp.ncbi.nlm.nih.gov/pub/clinvar/.")
        return None
    try:
        variants = []
        with gzip.open(file_path, 'rt') as f:
            for line in f:
                if line.startswith('#'):
                    continue
                fields = line.strip().split('\t')
                if len(fields) > 7:
                    gene = fields[7].split('GENEINFO=')[1].split(':')[0] if 'GENEINFO=' in fields[7] else 'Unknown'
                    disease = fields[7].split('CLNDISDB=')[1].split(',')[0] if 'CLNDISDB=' in fields[7] else 'Unknown'
                    variants.append({'gene': gene, 'disease': disease})
        return pd.DataFrame(variants)
    except Exception as e:
        print(f"Error parsing ClinVar file: {e}")
        return None

# Main execution
if __name__ == "__main__":
    # Create simulated dataset
    print("Creating simulated dataset...")
    sim_data = create_simulated_dataset()
    print("Simulated dataset preview:")
    print(sim_data.head())

    # Example: Load Orphanet data (replace with actual file path)
    orphanet_file = 'en_product1.xml'  # Update with downloaded file
    orphanet_data = load_orphanet_data(orphanet_file)
    if orphanet_data is not None:
        print("\nOrphanet data preview:")
        print(orphanet_data.head())

    # Example: Load ClinVar data (replace with actual file path)
    clinvar_file = 'clinvar_20250526.vcf.gz'  # Update with downloaded file
    clinvar_data = load_clinvar_data(clinvar_file)
    if clinvar_data is not None:
        print("\nClinVar data preview:")
        print(clinvar_data.head())
# Out:
# Creating simulated dataset...
# Simulated dataset preview:
#    patient_id            symptoms dna_mutations                disease
# 0           0  seizures,weak_legs          CLN3         Batten Disease
# 1           1      rashes,fatigue         SNRPN  Prader-Willi Syndrome
# 2           2  seizures,weak_legs          CLN3         Batten Disease
# 3           3      rashes,fatigue         SNRPN  Prader-Willi Syndrome
# 4           4  seizures,weak_legs          CLN3         Batten Disease
# Orphanet file en_product1.xml not found. Please download from www.orphadata.org.
# ClinVar file clinvar_20250526.vcf.gz not found. Please download from ftp.ncbi.nlm.nih.gov/pub/clinvar/.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf

# Load simulated dataset (or replace with real Orphanet/ClinVar data)
def load_data(file_path='simulated_rare_disease_data.csv'):
    return pd.read_csv(file_path)

# Encode symptoms using BERT
def get_symptom_embeddings(symptoms, tokenizer, model):
    inputs = tokenizer(symptoms, return_tensors='tf', padding=True, truncation=True, max_length=50)
    outputs = model(inputs)
    return outputs.pooler_output.numpy()  # Use pooler output as embedding

# Preprocess data
def preprocess_data(df):
    # Initialize BERT for symptom encoding
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    bert_model = TFBertModel.from_pretrained('bert-base-uncased')

    # Encode symptoms
    symptom_embeddings = np.vstack([get_symptom_embeddings(s, tokenizer, bert_model) for s in df['symptoms']])

    # Encode DNA mutations
    le_dna = LabelEncoder()
    dna_encoded = le_dna.fit_transform(df['dna_mutations']).reshape(-1, 1)

    # Encode disease labels
    le_disease = LabelEncoder()
    disease_encoded = le_disease.fit_transform(df['disease'])

    # Combine features
    X = np.hstack([symptom_embeddings, dna_encoded])
    y = disease_encoded

    return X, y, le_disease

# Main execution
if __name__ == "__main__":
    # Load data
    df = load_data()
    print("Dataset preview:")
    print(df.head())

    # Preprocess
    X, y, le_disease = preprocess_data(df)
    print("\nFeature matrix shape:", X.shape)
    print("Label array shape:", y.shape)
    print("Sample features (first patient):", X[0])
    print("Sample label (first patient):", le_disease.inverse_transform([y[0]])[0])
# Out:
# Dataset preview:
#    patient_id            symptoms dna_mutations                disease
# 0           0  seizures,weak_legs          CLN3         Batten Disease
# 1           1      rashes,fatigue         SNRPN  Prader-Willi Syndrome
# 2           2  seizures,weak_legs          CLN3         Batten Disease
# 3           3      rashes,fatigue         SNRPN  Prader-Willi Syndrome
# 4           4  seizures,weak_legs          CLN3         Batten Disease
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Feature matrix shape: (100, 769)
# Label array shape: (100,)
# Sample features (first patient): [-7.60976493e-01 -3.02741408e-01 -8.45005035e-01  5.83074152e-01
#   5.72498858e-01 -3.89211774e-02  5.37022769e-01  3.52610081e-01
#  -8.03164423e-01 -9.99890029e-01 -1.66006774e-01  8.82745504e-01
#   9.60429609e-01  5.28743505e-01  8.50163043e-01 -6.67895615e-01
#  -3.17013443e-01 -5.56456804e-01  1.73028275e-01 -1.32282019e-01
#   6.10614479e-01  9.99935627e-01 -8.70647356e-02  3.45444798e-01
#   5.68816721e-01  9.58646178e-01 -7.03498840e-01  8.05121183e-01
#   9.24449742e-01  6.20209992e-01 -5.38871586e-01  2.93516189e-01
#  -9.81759191e-01 -3.77630770e-01 -8.86604309e-01 -9.77422476e-01
#   2.83212423e-01 -5.34240484e-01 -1.18399814e-01 -4.42461483e-02
#  -7.74932206e-01  3.72729659e-01  9.99766886e-01  1.01229642e-02
#   3.83617461e-01 -2.55459279e-01 -9.99994934e-01  3.52360755e-01
#  -6.75185978e-01  8.46498132e-01  7.96734869e-01  8.10377777e-01
#   2.14764804e-01  4.31967139e-01  4.17867333e-01 -4.89329696e-01
#   2.98501384e-02  1.99049413e-01 -2.37586126e-01 -5.26838362e-01
#  -6.16553724e-01  4.85836208e-01 -7.54320860e-01 -8.37674558e-01
#   8.71740222e-01  5.30246496e-01 -3.83298993e-01 -3.77697438e-01
#  -1.50164440e-02 -1.21950470e-01  6.21809721e-01  4.20995086e-01
#  -2.04286322e-01 -8.08661520e-01  6.31541252e-01  3.65141153e-01
#  -6.80994749e-01  1.00000000e+00 -4.74919438e-01 -9.57842767e-01
#   7.02021718e-01  6.17063582e-01  5.98156393e-01 -2.77780801e-01
#   2.14266956e-01 -1.00000000e+00  5.18923759e-01 -2.03092590e-01
#  -9.78649914e-01  3.07449430e-01  4.22599196e-01 -2.63714135e-01
#   5.16470373e-01  6.24560595e-01 -5.53170502e-01 -5.12599051e-01
#  -1.08582571e-01 -5.82282662e-01 -3.62638563e-01 -5.14587283e-01
#   1.03904113e-01 -2.82723546e-01 -4.85946029e-01 -2.13477597e-01
#   3.81274879e-01 -5.28686583e-01 -1.13767840e-01  1.89855590e-01
#   1.55366868e-01  6.42882168e-01  4.78667915e-01 -4.27075565e-01
#   4.50723886e-01 -9.06497717e-01  5.70151985e-01 -3.64532113e-01
#  -9.83968675e-01 -6.53406441e-01 -9.80017245e-01  5.77052295e-01
#  -1.76503628e-01 -4.24755543e-01  8.34787250e-01 -1.69576839e-01
#   2.95183480e-01 -1.05437331e-01 -7.57737279e-01 -1.00000000e+00
#  -4.82205212e-01 -5.03476083e-01 -2.40705058e-01 -3.26107472e-01
#  -9.53720033e-01 -9.35266972e-01  5.85569739e-01  8.57627273e-01
#   1.65086344e-01  9.99091983e-01 -3.50777775e-01  8.97650898e-01
#  -2.69577384e-01 -7.47483373e-01  4.73982900e-01 -4.41628009e-01
#   7.04909742e-01 -1.98735639e-01 -3.30433607e-01  2.13518098e-01
#  -2.41476536e-01  2.59827614e-01 -4.52310979e-01 -2.45824888e-01
#  -7.07594037e-01 -8.23613822e-01 -3.23876828e-01  9.00776863e-01
#  -5.11648297e-01 -8.43720615e-01 -5.95715232e-02 -2.60279536e-01
#  -4.15318847e-01  7.17482746e-01  7.41820037e-01  3.72003406e-01
#  -3.94032985e-01  5.51972330e-01  1.68345630e-01  3.69401842e-01
#  -6.51158869e-01 -5.23879193e-02  3.64307672e-01 -4.00674731e-01
#  -6.97021902e-01 -9.66691434e-01 -3.84505808e-01  3.91170561e-01
#   9.69898880e-01  4.73454922e-01  2.97416657e-01  5.99950194e-01
#  -2.25367680e-01  6.38181150e-01 -9.39864933e-01  9.61484253e-01
#  -2.68666685e-01  3.01590860e-01 -9.82394218e-02  5.29067755e-01
#  -6.56032383e-01  1.89175338e-01  6.60116255e-01 -4.24384326e-01
#  -6.81574225e-01 -1.72695294e-01 -4.27381665e-01 -4.27683294e-01
#  -7.12940037e-01  2.28967458e-01 -3.74916464e-01 -3.33117366e-01
#  -1.88577220e-01  8.29010904e-01  9.36574340e-01  4.58901823e-01
#   2.67286420e-01  5.80530941e-01 -7.88301051e-01 -3.21622223e-01
#   1.53292596e-01  2.42789492e-01  2.81316072e-01  9.84937072e-01
#  -5.61018050e-01 -2.44005784e-01 -8.77203465e-01 -9.78496730e-01
#  -1.46009307e-02 -8.44603300e-01 -9.11076516e-02 -4.79617417e-01
#   6.31033182e-01  5.68678342e-02  1.34572700e-01  3.67854059e-01
#  -8.12816381e-01 -6.18508816e-01  3.40446919e-01 -3.46870422e-01
#   3.61558765e-01 -3.63647819e-01  6.92098439e-01  9.31461751e-01
#  -3.06051344e-01  5.47467709e-01  9.17322576e-01 -7.49805033e-01
#  -7.27984548e-01  6.84900045e-01 -2.22816601e-01  6.81734324e-01
#  -6.69168890e-01  9.63442922e-01  7.47806013e-01  7.16762066e-01
#  -8.61711323e-01 -7.17043400e-01 -6.72088981e-01 -6.04448378e-01
#  -2.84519583e-01 -2.16841072e-01  7.67769158e-01  6.19363725e-01
#   4.76773560e-01  3.62699419e-01 -5.15088916e-01  9.46376741e-01
#  -4.77313399e-01 -9.33319569e-01 -4.95318383e-01 -1.99427202e-01
#  -9.81790662e-01  8.32772017e-01  3.80224884e-01  3.12595338e-01
#  -3.34951222e-01 -5.93806565e-01 -9.28488731e-01  6.77833915e-01
#   2.01656312e-01  8.90231729e-01 -1.89357519e-01 -8.15957189e-01
#  -6.78196788e-01 -8.98957372e-01  1.59401051e-03 -1.64655641e-01
#  -3.27523112e-01  3.92232165e-02 -8.93638849e-01  4.52845544e-01
#   3.23229700e-01  4.45964515e-01 -7.47631431e-01  9.81433034e-01
#   9.99999523e-01  9.13947046e-01  8.27363372e-01  6.28591776e-01
#  -9.99329627e-01 -5.99748135e-01  9.99946415e-01 -9.80573058e-01
#  -1.00000000e+00 -8.46176922e-01 -7.06579804e-01  2.39373147e-01
#  -1.00000000e+00 -2.93696672e-01 -1.12692602e-01 -8.30140769e-01
#   6.61055565e-01  9.24523532e-01  9.18821514e-01 -1.00000000e+00
#   6.10364139e-01  8.40255916e-01 -6.65574014e-01  9.03404295e-01
#  -4.84663576e-01  9.50849235e-01  4.87221599e-01  5.37412047e-01
#  -1.58511445e-01  3.82088006e-01 -9.33099151e-01 -7.50298023e-01
#  -3.34378541e-01 -6.79375827e-01  9.93003011e-01  3.25499207e-01
#  -7.40240276e-01 -8.06138515e-01  2.71735132e-01 -2.44925216e-01
#   8.48521292e-02 -9.29111600e-01 -2.72838384e-01  3.68210167e-01
#   7.99652219e-01  5.27800992e-02  1.88678712e-01 -4.31545019e-01
#   2.89357752e-01  1.18752956e-01 -1.79526880e-02  6.44634724e-01
#  -8.95116627e-01 -4.10393894e-01 -7.09633708e-01 -6.40702695e-02
#  -5.22452533e-01 -9.48656738e-01  9.40291703e-01 -4.54032332e-01
#   6.88737512e-01  1.00000000e+00  1.57930821e-01 -7.15846419e-01
#   5.71354389e-01  3.05248320e-01 -1.63022831e-01  1.00000000e+00
#   8.03555131e-01 -9.50199008e-01 -5.67608953e-01  6.94465041e-01
#  -5.73715091e-01 -6.36311293e-01  9.97682512e-01 -2.97616661e-01
#  -4.80488092e-01 -1.04555599e-01  9.73754227e-01 -9.82120454e-01
#   9.86711144e-01 -6.87583506e-01 -9.14919198e-01  9.21394348e-01
#   8.66389751e-01 -5.10861874e-01 -4.87761468e-01  1.99116081e-01
#  -4.42738265e-01  3.36043060e-01 -7.26154387e-01  6.64462566e-01
#   3.43454927e-01 -1.17349140e-01  8.51564825e-01 -6.09338641e-01
#  -6.12108052e-01  2.85425931e-01 -6.42047465e-01 -4.30061035e-02
#   8.42169940e-01  5.16807854e-01 -4.05322611e-01  1.00923464e-01
#  -4.21152204e-01 -3.91092211e-01 -9.36268806e-01  6.12003207e-01
#   1.00000000e+00 -4.81512547e-01  6.45881176e-01 -3.11604083e-01
#  -4.94248345e-02  1.86909631e-01  4.98206437e-01  5.29644310e-01
#  -4.20990527e-01 -6.00800097e-01  6.10680997e-01 -8.49287510e-01
#  -9.85884666e-01  5.89949787e-01  2.93500990e-01 -3.20959806e-01
#   9.99875605e-01  2.85214961e-01  2.52808899e-01  3.68454546e-01
#   9.47458327e-01 -8.19005072e-02  3.22618246e-01  6.91113472e-01
#   9.53086793e-01 -3.76136065e-01  6.21630073e-01  5.65607607e-01
#  -8.41311216e-01 -2.23067805e-01 -6.30482793e-01  1.36180967e-01
#  -9.10079718e-01 -9.14520472e-02 -8.55048120e-01  9.13977623e-01
#   9.05598223e-01  3.74803364e-01  2.19791055e-01  6.38834119e-01
#   1.00000000e+00 -7.35615194e-01  5.84289551e-01 -5.81785515e-02
#   6.48329556e-01 -9.98568535e-01 -4.68568563e-01 -3.82751048e-01
#  -5.30937202e-02 -7.33248234e-01 -3.29823077e-01  3.21529567e-01
#  -9.16150630e-01  5.63320577e-01  4.71397817e-01 -9.18745816e-01
#  -9.79076862e-01 -3.10852557e-01  5.93853951e-01  2.15062857e-01
#  -9.52818632e-01 -6.53734088e-01 -5.07582605e-01  4.11835998e-01
#  -4.02210027e-01 -8.79131734e-01 -7.08459094e-02 -4.36673224e-01
#   4.40226495e-01 -2.75455624e-01  5.87152243e-01  6.45855725e-01
#   6.83596253e-01 -6.18808329e-01 -5.70582986e-01 -2.76280105e-01
#  -6.75592124e-01  7.58526862e-01 -5.36143482e-01 -8.27550471e-01
#  -2.28039473e-01  1.00000000e+00 -4.94364798e-01  8.27651680e-01
#   5.65029860e-01  4.44214612e-01 -1.67597175e-01  4.03341532e-01
#   8.35255444e-01  2.08178893e-01 -6.54730797e-01 -7.31282651e-01
#  -2.32682750e-01 -2.85964191e-01  5.23891091e-01  4.06895876e-01
#   3.86384726e-01  7.08623886e-01  5.92675745e-01  3.21371168e-01
#  -2.99926940e-02  1.31633401e-01  9.84195530e-01 -1.74383178e-01
#  -3.06441456e-01 -2.63571590e-01 -2.34015182e-01 -3.77447128e-01
#   2.83698086e-02  1.00000000e+00  5.19613743e-01  3.56400043e-01
#  -9.88132477e-01 -7.48360932e-01 -7.40755975e-01  9.99998629e-01
#   7.53323138e-01 -5.47559440e-01  7.06782162e-01  6.80547774e-01
#  -1.33624598e-01  5.66056013e-01 -2.80065030e-01 -3.63811195e-01
#   3.33286494e-01  2.80318111e-01  8.66423965e-01 -6.81979656e-01
#  -9.45370495e-01 -6.09024763e-01  4.30312574e-01 -9.20163393e-01
#   9.99696612e-01 -6.23625100e-01 -2.35381126e-01 -3.86462450e-01
#  -1.67871043e-01 -1.44127801e-01 -1.36596989e-03 -9.55055535e-01
#  -1.43017143e-01  3.14445406e-01  9.22922552e-01  1.76439494e-01
#  -5.58661222e-01 -7.85223246e-01  7.47545600e-01  6.69371426e-01
#  -7.51426458e-01 -8.74139190e-01  9.46186602e-01 -9.27060843e-01
#   6.46206319e-01  9.99999642e-01  3.77764255e-01  6.18317984e-02
#   3.06011766e-01 -2.36391887e-01  2.51744837e-01 -2.79945582e-01
#   6.14139080e-01 -8.92594814e-01 -3.90085220e-01 -1.68002576e-01
#   2.44150907e-01 -1.92757100e-01 -4.41371322e-01  6.21716857e-01
#   2.02444553e-01 -6.13913536e-01 -4.97247607e-01 -1.06760636e-01
#   4.63878512e-01  7.83316195e-01 -3.11974019e-01 -2.97793001e-01
#   2.89576828e-01 -1.23401672e-01 -8.46687257e-01 -3.74912798e-01
#  -3.28282923e-01 -9.99961376e-01  4.77887243e-01 -1.00000000e+00
#   6.15939319e-01  1.68342311e-02 -2.29178131e-01  7.28493869e-01
#   5.70151269e-01  5.89444757e-01 -4.98190731e-01 -7.13160932e-01
#   4.11840409e-01  6.91959143e-01 -2.96200782e-01 -4.72605139e-01
#  -4.84309405e-01  4.78201419e-01 -1.59574345e-01  1.94282383e-01
#  -6.13429785e-01  6.86797321e-01 -1.47070855e-01  1.00000000e+00
#   2.22890437e-01 -5.50947785e-01 -8.71902287e-01  2.19091117e-01
#  -3.51978958e-01  9.99999642e-01 -6.32493973e-01 -9.28877532e-01
#   3.24444830e-01 -6.16117477e-01 -7.19403028e-01  4.23114896e-01
#   7.28523657e-02 -7.23793328e-01 -8.20151865e-01  8.74818444e-01
#   8.15926671e-01 -6.46497726e-01  5.37277699e-01 -2.86802471e-01
#  -5.05776048e-01  1.53750062e-01  7.31435776e-01  9.77806628e-01
#   1.35793135e-01  6.56415224e-01 -7.10201785e-02 -4.71796766e-02
#   9.22890127e-01  1.01661913e-01  1.57303303e-01  1.92743927e-01
#   1.00000000e+00  4.72789824e-01 -8.35238993e-01 -2.06096489e-02
#  -8.67233455e-01 -4.42479253e-01 -7.83545017e-01  3.23534787e-01
#   4.49373513e-01  7.59775758e-01 -3.11593503e-01  9.27571535e-01
#  -4.92096692e-01 -6.57954603e-04 -6.69217348e-01 -3.36982816e-01
#   4.98264104e-01 -8.41339052e-01 -9.68998194e-01 -9.72397804e-01
#   4.87559766e-01 -4.04244006e-01 -2.07968578e-01  2.00819850e-01
#   1.98391080e-01  3.13008487e-01  4.41219658e-01 -1.00000000e+00
#   8.67327154e-01  4.46580529e-01  8.02872181e-01  9.43331242e-01
#   6.73871934e-01  5.99445820e-01  2.10889637e-01 -9.70971942e-01
#  -8.26594889e-01 -3.25870723e-01 -3.76458436e-01  5.81359804e-01
#   5.39925456e-01  6.70243204e-01  4.20816869e-01 -5.32333076e-01
#  -2.78875321e-01 -4.85048383e-01 -6.19555593e-01 -9.80132103e-01
#   4.94138718e-01 -4.71884519e-01 -7.73037791e-01  9.31582570e-01
#  -2.04325899e-01 -1.96612939e-01 -2.30100229e-02 -7.24931479e-01
#   7.05279291e-01  6.46756589e-01  2.57418334e-01  5.30824065e-02
#   3.49322617e-01  8.16047728e-01  8.50023210e-01  9.76308286e-01
#  -7.72054315e-01  4.70932662e-01 -6.95293546e-01  4.29081619e-01
#   7.70326257e-01 -8.70684624e-01  1.73302501e-01  2.84454167e-01
#  -4.23512340e-01  3.16646367e-01 -3.08424562e-01 -8.24257553e-01
#   7.95289993e-01 -3.27289164e-01  4.01339978e-01 -2.09100097e-01
#  -1.59998033e-02 -5.02511680e-01 -2.47285903e-01 -7.12925076e-01
#  -5.72915077e-01  6.53216898e-01  2.05029801e-01  7.40670979e-01
#   5.97253084e-01 -4.15988117e-02 -6.94377303e-01 -2.49396458e-01
#  -6.09255791e-01 -8.55623305e-01  6.96047544e-01 -9.18606445e-02
#  -1.49134472e-01  7.04269767e-01 -1.00257754e-01  7.68282473e-01
#   1.29562482e-01 -3.83806497e-01 -2.90419698e-01 -4.63657618e-01
#   6.36193275e-01 -4.39803958e-01 -6.33771062e-01 -4.62049872e-01
#   5.74616671e-01  3.92722487e-01  9.99911845e-01 -6.81485295e-01
#  -7.93414354e-01 -2.96683580e-01 -4.07258898e-01  4.25750315e-01
#  -4.39502746e-01 -1.00000000e+00  4.85438108e-01 -5.66893399e-01
#   3.22778732e-01 -5.98562717e-01  7.55274713e-01 -7.46917129e-01
#  -9.18124378e-01 -3.27155739e-01  4.67620224e-01  5.80155969e-01
#  -5.02190650e-01 -7.00716436e-01  5.28160334e-01 -9.96710137e-02
#   8.81586194e-01  6.19045734e-01 -3.39970350e-01  3.72182578e-04
#   6.48786366e-01 -6.43624783e-01 -7.15207875e-01  7.99724400e-01
#   0.00000000e+00]
# Sample label (first patient): Batten Disease

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load preprocessed data
def load_preprocessed_data():
    df = pd.read_csv('simulated_rare_disease_data.csv')
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    bert_model = TFBertModel.from_pretrained('bert-base-uncased')
    symptom_embeddings = np.vstack([get_symptom_embeddings(s, tokenizer, bert_model) for s in df['symptoms']])
    le_dna = LabelEncoder()
    dna_encoded = le_dna.fit_transform(df['dna_mutations']).reshape(-1, 1)
    X = np.hstack([symptom_embeddings, dna_encoded])
    return X, le_dna

def get_symptom_embeddings(symptoms, tokenizer, model):
    inputs = tokenizer(symptoms, return_tensors='tf', padding=True, truncation=True, max_length=50)
    outputs = model(inputs)
    return outputs.pooler_output.numpy()

# Define VAE
class VAE(tf.keras.Model):
    def __init__(self, input_dim, latent_dim):
        super(VAE, self).__init__()
        self.encoder = tf.keras.Sequential([
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(latent_dim * 2)  # Mean and log variance
        ])
        self.decoder = tf.keras.Sequential([
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(input_dim, activation='sigmoid')
        ])

    def call(self, inputs):
        mean_logvar = self.encoder(inputs)
        mean, logvar = tf.split(mean_logvar, num_or_size_splits=2, axis=1)
        epsilon = tf.random.normal(tf.shape(mean))
        z = mean + tf.exp(0.5 * logvar) * epsilon
        return self.decoder(z)

# Generate synthetic data
def generate_synthetic_data(vae, n_samples, le_dna):
    z_sample = tf.random.normal([n_samples, 10])
    X_synthetic = vae.decoder(z_sample).numpy()
    synthetic_dna = le_dna.inverse_transform(np.argmax(X_synthetic[:, -1:], axis=1))
    synthetic_data = pd.DataFrame({
        'patient_id': range(100, 100 + n_samples),
        'symptoms': ['synthetic_symptoms'] * n_samples,  # Placeholder
        'dna_mutations': synthetic_dna,
        'disease': ['Unknown'] * n_samples
    })
    return synthetic_data

# Main execution
if __name__ == "__main__":
    # Load preprocessed data
    X, le_dna = load_preprocessed_data()
    print("Feature matrix shape:", X.shape)

    # Train VAE
    vae = VAE(input_dim=X.shape[1], latent_dim=10)
    vae.compile(optimizer='adam', loss='mse')
    vae.fit(X, X, epochs=10, batch_size=32, verbose=1)

    # Generate synthetic data
    synthetic_data = generate_synthetic_data(vae, 50, le_dna)
    print("\nSynthetic dataset preview:")
    print(synthetic_data.head())
    synthetic_data.to_csv('synthetic_rare_disease_data.csv', index=False)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Feature matrix shape: (100, 769)
# Epoch 1/10
# 4/4 [==============================] - 1s 12ms/step - loss: 0.6941
# Epoch 2/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6105
# Epoch 3/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4550
# Epoch 4/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3314
# Epoch 5/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2828
# Epoch 6/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2555
# Epoch 7/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2462
# Epoch 8/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2390
# Epoch 9/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2345
# Epoch 10/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2318
#
# Synthetic dataset preview:
#    patient_id            symptoms dna_mutations  disease
# 0         100  synthetic_symptoms          CLN3  Unknown
# 1         101  synthetic_symptoms          CLN3  Unknown
# 2         102  synthetic_symptoms          CLN3  Unknown
# 3         103  synthetic_symptoms          CLN3  Unknown
# 4         104  synthetic_symptoms          CLN3  Unknown

# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.4.26)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.3 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
import pandas as pd
import numpy as np
import torch
import torch_geometric as pyg
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.preprocessing import LabelEncoder

# Load data
def load_data():
    real_data = pd.read_csv('simulated_rare_disease_data.csv')
    synthetic_data = pd.read_csv('synthetic_rare_disease_data.csv')
    return real_data, synthetic_data

# Preprocess (simplified, assumes preprocessed features from Step 2)
def preprocess_data(real_data, synthetic_data):
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    bert_model = TFBertModel.from_pretrained('bert-base-uncased')

    def get_symptom_embeddings(symptoms):
        inputs = tokenizer(symptoms, return_tensors='tf', padding=True, truncation=True, max_length=50)
        outputs = bert_model(inputs)
        return outputs.pooler_output.numpy()

    # Encode real data
    real_embeddings = np.vstack([get_symptom_embeddings(s) for s in real_data['symptoms']])
    le_dna = LabelEncoder()
    real_dna = le_dna.fit_transform(real_data['dna_mutations']).reshape(-1, 1)
    le_disease = LabelEncoder()
    real_labels = le_disease.fit_transform(real_data['disease'])
    X_real = np.hstack([real_embeddings, real_dna])

    # Encode synthetic data (ignore 'Unknown' labels)
    synth_embeddings = np.vstack([get_symptom_embeddings(s) for s in synthetic_data['symptoms']])
    synth_dna = le_dna.transform(synthetic_data['dna_mutations']).reshape(-1, 1)
    X_synth = np.hstack([synth_embeddings, synth_dna])

    # Combine
    X = np.vstack([X_real, X_synth])
    y = np.concatenate([real_labels, [-1] * len(synthetic_data)])  # -1 for unlabeled synthetic data
    return X, y, le_disease

# Create graph
def create_graph(X, symptoms):
    edge_index = []
    for i in range(len(symptoms)):
        for j in range(i + 1, len(symptoms)):
            if symptoms[i] == symptoms[j]:  # Connect patients with same symptoms
                edge_index.append([i, j])
                edge_index.append([j, i])
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    return Data(x=torch.tensor(X, dtype=torch.float), edge_index=edge_index)

# Define GNN
class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return torch.log_softmax(x, dim=1)

# Main execution
if __name__ == "__main__":
    # Load and preprocess
    real_data, synthetic_data = load_data()
    X, y, le_disease = preprocess_data(real_data, synthetic_data)
    graph_data = create_graph(X, real_data['symptoms'].tolist() + synthetic_data['symptoms'].tolist())

    # Train GNN
    model = GNN(input_dim=X.shape[1], hidden_dim=64, num_classes=len(le_disease.classes_))
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    model.train()
    for epoch in range(50):
        optimizer.zero_grad()
        out = model(graph_data)
        mask = y != -1  # Only use labeled data for loss
        loss = torch.nn.functional.nll_loss(out[mask], torch.tensor(y[mask], dtype=torch.long))
        loss.backward()
        optimizer.step()
        if epoch % 10 == 0:
            print(f'Epoch {epoch}, Loss: {loss.item()}')

    # Predict and explain
    model.eval()
    with torch.no_grad():
        pred = model(graph_data).argmax(dim=1)
        pred_diseases = le_disease.inverse_transform(pred[y != -1])

    for i, patient in real_data.iterrows():
        explanation = f"Predicted {pred_diseases[i]} due to symptoms: {patient['symptoms']} and mutation: {patient['dna_mutations']}"
        print(explanation)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Epoch 0, Loss: 0.9911831021308899
# Epoch 10, Loss: 0.4904930889606476
# Epoch 20, Loss: 0.19353900849819183
# Epoch 30, Loss: 0.049214690923690796
# Epoch 40, Loss: 0.015301075764000416
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Batten Disease due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN

# %%
import pandas as pd
import numpy as np
import torch
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.preprocessing import LabelEncoder
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf

# Preprocess data (adapted to handle only real data)
def preprocess_data(real_data):
    # Initialize BERT for symptom encoding
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    bert_model = TFBertModel.from_pretrained('bert-base-uncased')

    def get_symptom_embeddings(symptoms):
        inputs = tokenizer(symptoms, return_tensors='tf', padding=True, truncation=True, max_length=50)
        outputs = bert_model(inputs)
        return outputs.pooler_output.numpy()

    # Encode symptoms
    symptom_embeddings = np.vstack([get_symptom_embeddings(s) for s in real_data['symptoms']])

    # Encode DNA mutations
    le_dna = LabelEncoder()
    dna_encoded = le_dna.fit_transform(real_data['dna_mutations']).reshape(-1, 1)

    # Encode disease labels
    le_disease = LabelEncoder()
    disease_encoded = le_disease.fit_transform(real_data['disease'])

    # Combine features
    X = np.hstack([symptom_embeddings, dna_encoded])
    y = disease_encoded

    return X, y, le_disease

# Create graph
def create_graph(X, symptoms):
    edge_index = []
    for i in range(len(symptoms)):
        for j in range(i + 1, len(symptoms)):
            if symptoms[i] == symptoms[j]:  # Connect patients with same symptoms
                edge_index.append([i, j])
                edge_index.append([j, i])
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    return Data(x=torch.tensor(X, dtype=torch.float), edge_index=edge_index)

# Define GNN
class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return torch.log_softmax(x, dim=1)

# Load data and model
def load_data_and_model():
    real_data = pd.read_csv('simulated_rare_disease_data.csv')
    X, y, le_disease = preprocess_data(real_data)
    graph_data = create_graph(X, real_data['symptoms'].tolist())
    model = GNN(input_dim=X.shape[1], hidden_dim=64, num_classes=len(le_disease.classes_))
    return real_data, graph_data, model, le_disease

# Basic explainability
def explain_prediction(patient, prediction, le_disease):
    disease = le_disease.inverse_transform([prediction])[0]
    return f"Predicted {disease} due to symptoms: {patient['symptoms']} and mutation: {patient['dna_mutations']}"

# Main execution
if __name__ == "__main__":
    # Load and preprocess
    real_data, graph_data, model, le_disease = load_data_and_model()
    model.eval()
    with torch.no_grad():
        pred = model(graph_data).argmax(dim=1)

    for i, patient in real_data.iterrows():
        explanation = explain_prediction(patient, pred[i], le_disease)
        print(explanation)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN
# Predicted Prader-Willi Syndrome due to symptoms: seizures,weak_legs and mutation: CLN3
# Predicted Prader-Willi Syndrome due to symptoms: rashes,fatigue and mutation: SNRPN

# %%
import google.generativeai as genai
import os
import pandas as pd
import json

# Configure Gemini API
def configure_gemini(api_key):
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel('gemini-2.0-flash')
    return model

# Load simulated dataset (for context in prompts)
def load_data():
    return pd.read_csv('simulated_rare_disease_data.csv')

# Prompt 1: Why the GNN model selected a specific prediction
def get_why_prediction_prompt(data):
    sample_patient = data.iloc[0]  # Example patient
    return f"""
You are an expert in machine learning and explainable AI, with knowledge of Graph Neural Networks (GNNs) for rare disease detection. A GNN model uses a simulated dataset with patient data, including symptoms (e.g., "{sample_patient['symptoms']}"), DNA mutations (e.g., "{sample_patient['dna_mutations']}"), and disease labels (e.g., "{sample_patient['disease']}"). The GNN represents patients as nodes, connected by edges based on shared symptoms, using BERT embeddings for symptoms and LabelEncoder for DNA mutations. SHAP (Shapley Additive Explanations) provides feature importance.

For a patient with symptoms "{sample_patient['symptoms']}" and DNA mutation "{sample_patient['dna_mutations']}", the GNN predicts "{sample_patient['disease']}". Explain why the model selected this prediction. Describe how the GNN’s graph structure (patient connections via symptoms) and SHAP values highlight the contribution of symptoms and mutations to the prediction. Provide a clear, human-understandable explanation of the model’s decision-making process, focusing on symptom-mutation interactions in the graph.
"""

# Prompt 2: How the GNN model arrived at the prediction
def get_how_prediction_prompt(data):
    sample_patient = data.iloc[0]
    return f"""
You are an expert in Graph Neural Networks (GNNs) for healthcare. A GNN model for rare disease detection uses a simulated dataset with patient data (symptoms like "{sample_patient['symptoms']}", DNA mutations like "{sample_patient['dna_mutations']}", disease labels like "{sample_patient['disease']}"). Patients are nodes in a graph, with edges for shared symptoms. Features include BERT embeddings for symptoms and LabelEncoded DNA mutations. The model uses two GCNConv layers and SHAP for explainability.

For a patient with symptoms "{sample_patient['symptoms']}" and mutation "{sample_patient['dna_mutations']}", the model predicts "{sample_patient['disease']}". Explain how the GNN arrived at this conclusion, including:
1. Graph construction (edge creation based on symptom similarity).
2. Feature aggregation from neighboring nodes using GCNConv layers.
3. How aggregated features lead to the classification.
4. How SHAP values explain feature contributions.

Provide a technical yet clear explanation for someone familiar with machine learning but not GNNs.
"""

# Prompt 3: Next steps for prevention and control
def get_prevention_control_prompt(data):
    sample_patient = data.iloc[0]
    return f"""
You are a medical AI expert specializing in rare disease management. A GNN model for rare disease detection, trained on a simulated dataset with symptoms (e.g., "{sample_patient['symptoms']}"), DNA mutations (e.g., "{sample_patient['dna_mutations']}"), and disease labels (e.g., "{sample_patient['disease']}"), predicts diseases and uses SHAP for explanations. For patients predicted to have "{sample_patient['disease']}", suggest actionable steps to prevent and control the disease, including:
1. Preventive measures (e.g., genetic screening, lifestyle changes).
2. Control measures (e.g., medical interventions, therapies).
3. How the GNN’s predictions and SHAP explanations guide clinicians.
4. Public health strategies (e.g., patient registries, screening programs).

Base suggestions on medical best practices and recent research on rare disease management.
"""

# Main execution
if __name__ == "__main__":
    # Set your Gemini API key (replace with your key or use environment variable)
    API_KEY = os.getenv('AIzaSyDhhRDWMvhtbJWj9qgZKy79_b3pv_Co3Gg') or 'AIzaSyDhhRDWMvhtbJWj9qgZKy79_b3pv_Co3Gg'

    # Configure Gemini model
    model = configure_gemini(API_KEY)

    # Load simulated dataset for context
    data = load_data()

    # Get prompts
    prompt_why = get_why_prediction_prompt(data)
    prompt_how = get_how_prediction_prompt(data)
    prompt_prevention = get_prevention_control_prompt(data)

    # Send prompts to Gemini API and collect responses
    responses = {}
    for prompt_name, prompt_text in [
        ('why_prediction', prompt_why),
        ('how_prediction', prompt_how),
        ('prevention_control', prompt_prevention)
    ]:
        try:
            response = model.generate_content(prompt_text)
            responses[prompt_name] = response.text
            print(f"\nResponse for {prompt_name}:\n{response.text}")
        except Exception as e:
            print(f"Error processing {prompt_name}: {e}")
            responses[prompt_name] = f"Error: {e}"

    # Save responses to a JSON file
    with open('gemini_responses.json', 'w') as f:
        json.dump(responses, f, indent=4)
    print("\nResponses saved to 'gemini_responses.json'")
# Out:
# Response for why_prediction:
# Okay, let's break down how a GNN, trained on patient data for rare disease detection, might predict "Batten Disease" for a patient exhibiting "seizures, weak_legs" and carrying the "CLN3" mutation. We'll focus on the role of the graph structure, symptom-mutation interaction, and the insights provided by SHAP values.
#
# **Understanding the GNN Model Structure**
#
# 1.  **Node Representation (Patients):**  Each patient in the simulated dataset is represented as a node in the graph.  The node's "features" combine information about the patient's symptoms and their DNA mutations.
#
# 2.  **Feature Encoding:**
#     *   **Symptoms (BERT Embeddings):**  Symptoms are represented as text. Because GNNs work with numerical data, we use BERT (Bidirectional Encoder Representations from Transformers) to convert the symptom strings (e.g., "seizures,weak_legs") into numerical vectors (embeddings). BERT captures the semantic meaning of the symptoms and their relationships to each other.  For instance, it understands that "muscle weakness" and "weak legs" are similar.
#     *   **DNA Mutations (Label Encoding):** DNA mutations (e.g., "CLN3") are categorical data.  We use Label Encoding to convert them into numerical values.  So, "CLN3" might become the number "1," "ATP13A2" might become "2," and so on. While simple, it allows the GNN to process the mutation information. More sophisticated embedding methods could also be used for mutations.
#
# 3.  **Edges (Patient Connections):**  Edges connect patients who share similar symptoms. The more similar the symptoms, the stronger the connection (e.g., higher edge weight). The BERT embeddings are key here.  The similarity between the BERT embeddings of two patients' symptoms determines the weight of the edge connecting them.  So, patients with highly overlapping or semantically similar symptom profiles will have stronger connections.
#
# 4.  **GNN Layers (Message Passing):** The GNN architecture employs layers that aggregate information from neighboring nodes. During this "message passing," each node receives and integrates information about the features of its connected neighbors.  This allows the GNN to learn patterns and relationships between symptoms, mutations, and diseases across the entire patient population represented in the graph.  For example, it might learn that nodes with "seizures" as a key feature frequently connect to nodes with the "CLN3" mutation and eventually develop "Batten Disease."
#
# **Why Batten Disease Prediction?**
#
# Now, let's consider the specific patient with "seizures,weak_legs" and "CLN3" mutation.  Here's a possible scenario explaining the GNN's prediction of "Batten Disease":
#
# 1.  **Symptom Similarity in the Graph:** The patient's "seizures, weak_legs" symptom profile, represented as a BERT embedding, places them in a region of the graph densely populated by patients with similar symptom profiles.  This region contains many patients who were eventually diagnosed with Batten Disease.
#
# 2.  **Mutation Co-occurrence:** The patient also has the "CLN3" mutation. The GNN, through its training, has learned that the "CLN3" mutation is strongly associated with Batten Disease, *especially* in patients exhibiting seizure-related symptoms. It discovered this association during the message-passing phase. The GNN observed that nodes with mutations like "CLN3" that are connected to patient nodes with "seizures" and similar symptoms were frequently labeled with "Batten Disease."
#
# 3.  **Graph Neighborhood Influence:** The GNN's message-passing mechanism allows the patient node to "gather" information from its neighbors.  If a significant proportion of the patient's neighbors (patients with similar symptom profiles) have been diagnosed with Batten Disease and/or carry the "CLN3" mutation, the GNN will increase its confidence in predicting Batten Disease for this patient.
#
# **The Role of SHAP Values**
#
# SHAP (Shapley Additive Explanations) helps us understand the contribution of each feature (symptoms and mutations) to the GNN's prediction. SHAP assigns each feature a value reflecting its importance in pushing the prediction either towards or away from the final outcome.
#
# Here's how SHAP might work in this case:
#
# *   **High SHAP value for "seizures,weak_legs":**  The symptom "seizures,weak_legs" likely has a positive and high SHAP value. This suggests that the presence of these symptoms strongly contributed to the prediction of Batten Disease.  The SHAP value quantifies how much this specific symptom combination pushed the prediction towards Batten Disease, compared to the average prediction for all patients.
# *   **High SHAP value for "CLN3":** The "CLN3" mutation also has a positive and potentially high SHAP value. This indicates that the presence of this mutation also significantly contributed to the Batten Disease prediction. It's important to note that the SHAP value might be *higher* if the patient also had the "seizures, weak_legs" symptoms, illustrating the interaction effect between the mutation and the symptoms. This interaction effect captures the scenario where the CLN3 mutation is a much stronger predictor of Batten Disease in individuals showing seizures.
# *   **Interaction Effects (SHAP Interaction Values):**  Standard SHAP values only show the overall contribution of each feature.  SHAP *interaction* values reveal how features interact with each other.  In this case, a high positive SHAP interaction value between "seizures,weak_legs" and "CLN3" would confirm that the *combination* of these two factors is a strong predictor of Batten Disease, far stronger than either feature alone.
#
# **Human-Understandable Explanation (Simplified)**
#
# Imagine a network of patients. Patients are connected if they have similar symptoms.  This patient has "seizures, weak_legs" – symptoms that connect them to a cluster of other patients in the network.  Within that cluster, many patients have been diagnosed with Batten Disease and carry the "CLN3" mutation. The model "reasons" like this:
#
# "This patient has 'seizures, weak_legs.'  Patients with these symptoms are often linked to other patients who have Batten Disease.  This patient *also* has the 'CLN3' mutation, which is frequently found in Batten Disease patients, especially those with seizures. Therefore, based on the symptoms and the presence of the 'CLN3' mutation, and observing the disease outcomes of patients with similar symptom-mutation profiles in the network, I predict Batten Disease."
#
# **Key Takeaways**
#
# *   The GNN leverages the graph structure to learn relationships between symptoms, mutations, and diseases based on the entire patient population.
# *   The symptom-mutation interaction is crucial. The "CLN3" mutation might be less indicative of Batten Disease in the absence of certain symptoms like seizures.
# *   SHAP values provide a quantitative measure of feature importance, helping to understand which symptoms and mutations are driving the prediction and how they interact with each other.
# *   Explainable AI techniques like SHAP are critical for building trust in GNN models for healthcare applications, allowing clinicians to understand *why* a prediction was made and assess its validity.  They also help refine the model and identify potential biases.
#
#
# Response for how_prediction:
# Okay, let's break down how our GNN detects Batten Disease in a patient with seizures, weak legs, and the CLN3 mutation. We'll focus on how the graph structure, GCNConv layers, and SHAP analysis all contribute to the final prediction.
#
# **1. Graph Construction: Connecting Patients Based on Symptom Similarity**
#
# The first critical step is building the graph.  Each patient is represented as a **node** in the graph. The edges between nodes are crucial for information sharing, and in this case, they are based on shared symptoms. Here's how that might work:
#
# *   **Symptom-Based Edge Creation:**  Two patients are connected by an edge if they share symptoms. The more symptoms they share, the stronger the connection might be (e.g., a weighted edge).  This establishes a network where patients with similar symptom profiles are "neighbors".  For example:
#
#     *   Patient A: "seizures,weak_legs,vision_loss"
#     *   Patient B: "seizures,weak_legs,cognitive_decline"
#     *   Patient C: "fatigue,abdominal_pain"
#
#     Patient A and B would have an edge because they both have "seizures" and "weak_legs". Patient C would be relatively disconnected from A and B since they share no symptoms. There might be a threshold for edge creation; maybe they must share at least one symptom to form a direct edge.  Alternatively, more complex similarity metrics like Jaccard index could be used to calculate the similarity between symptom sets.
#
# *   **Implication:** This graph structure implicitly encodes the relationships between different patient profiles and creates opportunities for information sharing across patients with related symptom sets.
# **2. Feature Encoding:  Capturing the Patient Data**
#
# Each patient node has a feature vector associated with it that captures the crucial aspects of the patient's condition. These features are fed into the GNN. In this case, we have:
#
# *   **BERT Embeddings for Symptoms:** Natural language symptoms like "seizures,weak_legs" are converted into numerical representations using BERT (Bidirectional Encoder Representations from Transformers).  BERT is a powerful pre-trained language model.
#     *   **How BERT Helps:** Instead of treating symptoms as individual categorical features, BERT encodes the entire symptom description into a dense vector.  This captures semantic relationships between symptoms. For example, BERT will understand that "muscle weakness" is similar to "weak legs" even if they are not exactly the same. This avoids problems related to sparse one-hot encoding of potentially many symptoms.
#     *   **Output:**  The output of BERT is a fixed-length vector (e.g., 768 dimensions) that represents the meaning of the input symptom description.
#
# *   **Label-Encoded DNA Mutations:** The DNA mutation (e.g., "CLN3") is converted into a numerical representation using Label Encoding.
#     *   **Label Encoding:** Assigns a unique integer to each mutation type. For example, CLN3 -> 0, PPT1 -> 1, etc. This allows the mutation type to be used as a numeric feature. Note: Order matters in this encoding.
#     *   **Why Label Encoding over One-Hot?** If there are many different mutations, one-hot encoding could result in a very high-dimensional, sparse feature vector. Label encoding provides a more compact representation. If mutation types have an ordinal relation, then a different type of feature engineering may be needed.
# **3. Feature Aggregation with GCNConv Layers: Learning from Neighbors**
#
# This is where the magic of GNNs happens. The core of our model is the Graph Convolutional Network (GCN) layers, specifically `GCNConv` layers. Here's how they work:
#
# *   **GCNConv Layer Function:**  Each GCNConv layer takes the node features and the graph structure as input. For each node, it does the following:
#     1.  **Aggregate Neighbor Features:** It gathers the feature vectors from all the node's neighbors (patients with similar symptoms).
#     2.  **Transform Features:** It applies a learned linear transformation (a weight matrix) to the node's own feature vector and to the aggregated neighbor features.  This transformation projects the features into a new, potentially more informative, feature space.
#     3.  **Combine & Activate:** It combines the transformed node features and aggregated neighbor features (typically through a weighted average) and then applies a non-linear activation function (like ReLU). This non-linearity is crucial for learning complex relationships.
#
# *   **Why this is Powerful:** The GCNConv layer allows the model to learn how different combinations of symptoms and mutations, present in neighboring patients, might contribute to the disease. Information is effectively propagated across the graph, allowing the model to learn patterns from related patients.
#
# *   **Two GCNConv Layers:** Using two GCNConv layers allows the model to learn information from neighbors of neighbors. The first layer learns from direct neighbors, and the second layer learns from the neighbors of those neighbors, increasing the "receptive field" of the model.
#
# *   **In our example:**
#     *   The first GCNConv layer will aggregate information from other patients who have similar symptoms to our patient with "seizures,weak_legs" and CLN3. These other patients may have other mutations or slightly different symptom profiles.
#     *   The second GCNConv layer will aggregate information from patients who have similar symptoms to the first set of neighbors. This enables the model to capture more complex and indirect relationships.
#
# **4. Classification: From Aggregated Features to Disease Prediction**
#
# After the GCNConv layers, the final aggregated node features are passed to a classification layer (e.g., a fully connected neural network with a softmax output).
#
# *   **Classification Layer:** This layer maps the learned GNN representation of the patient (the output of the last GCNConv layer) to a probability distribution over the possible disease classes (e.g., Batten Disease, other rare diseases, no disease).
#
# *   **Prediction:**  The model predicts the disease with the highest probability. In this case, the model predicts "Batten Disease" because the aggregated features, derived from the patient's own symptoms and mutations and the features of similar patients in the graph, have been transformed in a way that strongly correlates with the "Batten Disease" class in the training data.
#
# **5. SHAP Values: Explaining Feature Contributions**
#
# SHAP (SHapley Additive exPlanations) values are used to explain the contribution of each feature (symptoms and mutations) to the final prediction.
#
# *   **What SHAP Values Do:** SHAP values quantify how much each feature (e.g., "seizures", "weak_legs", "CLN3") contributes to shifting the model's output away from the average prediction.  A positive SHAP value means the feature pushes the prediction towards Batten Disease, while a negative SHAP value means it pushes the prediction away from Batten Disease.
#
# *   **Calculating SHAP Values in GNNs:** Calculating SHAP values for GNNs is computationally challenging. There are several methods, including:
#
#     *   **GradientSHAP:** Approximates SHAP values using gradients.
#     *   **PathExplain:** Approximates SHAP values by considering different paths in the graph.
#
# *   **Interpreting SHAP Values for Our Patient:**
#     *   Let's say the SHAP value for "seizures" is +0.3, the SHAP value for "weak_legs" is +0.2, and the SHAP value for "CLN3" is +0.5.
#     *   This means that:
#         *   "CLN3" is the most important feature for this prediction, pushing the prediction the most towards Batten Disease.
#         *   "Seizures" and "weak_legs" also contribute to the prediction of Batten Disease, but to a lesser extent than "CLN3".
#
# *   **SHAP values explainability:**  They enable the user to understand which features are considered by the model to be the most relevant for the final decision.
#     *   Important: SHAP values don't tell us "why" a feature is important in a biological sense, only that the model is using it to make the prediction.  Further analysis might be needed to understand the underlying biological mechanisms.
#
# **In Summary:**
#
# Our GNN uses a graph structure to capture relationships between patients with similar symptoms. GCNConv layers aggregate features from neighboring patients, allowing the model to learn complex patterns related to rare disease diagnosis.  Finally, SHAP values provide insights into the contribution of each symptom and mutation to the final prediction, helping us understand why the model predicted Batten Disease for this specific patient. This approach leverages the power of both graph-based reasoning and feature attribution for more accurate and explainable rare disease detection.
#
#
# Response for prevention_control:
# Okay, I'm ready to analyze the Batten Disease prediction and provide actionable steps. Given the scenario – a GNN model predicting Batten Disease using symptoms, DNA mutations, and disease labels with SHAP explanations – here's my assessment and recommendations:
#
# **Understanding Batten Disease (Specifically CLN3-Related):**
#
# Batten Disease, particularly the CLN3 type, is a rare, inherited, neurodegenerative lysosomal storage disorder.  It primarily affects the nervous system. Symptoms typically begin in childhood and worsen over time. There is no cure, and treatment focuses on managing symptoms and improving quality of life. It is important to note that while the GNN identified Batten Disease and CLN3 mutation, Batten Disease has multiple subtypes caused by mutations in different genes (CLN1, CLN2, CLN3, CLN5, CLN6, CLN7, CLN8, CLN10, CLN11, CLN13, CLN14). Therefore, verification through genetic testing is paramount before confirming CLN3-related Batten Disease.
#
# **Actionable Steps for Patients Predicted to Have Batten Disease (CLN3 - with confirmation through genetic testing):**
#
# **1. Preventive Measures (Early Intervention & Family Planning):**
#
# *   **Genetic Counseling & Testing for Family Members:**
#     *   *Rationale:*  Batten Disease is autosomal recessive, meaning both parents must be carriers to pass it on.  Genetic counseling can inform parents and potential parents about the risk of having a child with Batten Disease. Testing of siblings and other relatives is crucial for identifying carriers who may want to consider their reproductive options.
#     *   *Action:* Refer the patient's parents and siblings for genetic counseling and CLN3 gene mutation testing. This includes discussing the inheritance pattern, risk assessment, and options for prenatal or preimplantation genetic diagnosis (PGD) in future pregnancies. Offer testing to extended family members.
# *   **Prenatal/Preimplantation Genetic Diagnosis (PGD):**
#     *   *Rationale:* If parents are confirmed carriers, prenatal diagnosis (amniocentesis or chorionic villus sampling) or PGD can determine if the fetus or embryo is affected by Batten Disease.
#     *   *Action:* Counsel carrier parents about these options when planning for future pregnancies.
# *   **Newborn Screening (If available and appropriate):**
#     *   *Rationale:*  While not currently standard for Batten Disease in many regions, research is ongoing to develop and implement newborn screening methods.  Early identification could lead to earlier intervention.
#     *   *Action:*  Advocate for the inclusion of Batten Disease (particularly specific subtypes for which effective screening is feasible) in newborn screening panels where appropriate. Check local and national guidelines for current recommendations.
#
# **2. Control Measures (Symptom Management & Supportive Care):**
#
# *   **Neurological Management:**
#     *   *Rationale:* Seizures, a common symptom, require careful management to prevent injury and improve quality of life. Progressive neurological decline necessitates a multidisciplinary approach.
#     *   *Action:*
#         *   **Antiepileptic Medications (AEDs):** Prescribe appropriate AEDs based on the type and frequency of seizures.  Monitor for side effects and adjust dosages as needed.  Consider a combination of medications if monotherapy is insufficient.
#         *   **Neuropsychological Assessment:** Regularly assess cognitive and behavioral changes.  Provide support and interventions to manage cognitive decline and behavioral problems.
#         *   **Physical and Occupational Therapy:** Maintain mobility and function for as long as possible.  Physical therapy can help with muscle weakness and spasticity. Occupational therapy can assist with adaptive equipment and strategies for daily living.
#         *   **Speech Therapy:** Address communication difficulties, including dysarthria (difficulty speaking) and dysphagia (difficulty swallowing).  Teach alternative communication methods as needed.
# *   **Vision Management:**
#     *   *Rationale:* Progressive vision loss is a hallmark of CLN3-related Batten Disease.
#     *   *Action:*
#         *   **Regular Ophthalmological Exams:** Monitor visual acuity and retinal changes.
#         *   **Low-Vision Aids:** Provide assistive devices such as magnifiers and screen readers to help with daily activities.
#         *   **Orientation and Mobility Training:**  Teach adaptive strategies for navigating environments safely with impaired vision.
# *   **Nutritional Support:**
#     *   *Rationale:*  Dysphagia and decreased appetite can lead to malnutrition.
#     *   *Action:*
#         *   **Dietary Consultation:**  Work with a registered dietitian to develop a meal plan that meets the patient's nutritional needs.
#         *   **Modified Food Textures:**  Provide pureed or soft foods to ease swallowing difficulties.
#         *   **Feeding Tube (If necessary):**  Consider a gastrostomy tube (G-tube) for long-term nutritional support if the patient is unable to maintain adequate nutrition orally.
# *   **Pulmonary Management:**
#     *   *Rationale:*  Weakness of respiratory muscles can lead to respiratory complications.
#     *   *Action:*
#         *   **Pulmonary Function Testing:**  Monitor lung function regularly.
#         *   **Chest Physiotherapy:**  Help clear secretions from the lungs.
#         *   **Vaccinations:**  Recommend annual influenza and pneumococcal vaccinations to prevent respiratory infections.
#         *   **Assisted Ventilation (If needed):**  Provide non-invasive or invasive ventilation as respiratory function declines.
# *   **Pain Management:**
#     *   *Rationale:* Muscle stiffness, seizures, and other complications can cause pain.
#     *   *Action:*  Use a multidisciplinary approach to pain management, including medications, physical therapy, and relaxation techniques.
# *   **Palliative Care:**
#     *   *Rationale:*  Batten Disease is a progressive and ultimately fatal illness.  Palliative care focuses on improving quality of life and providing comfort.
#     *   *Action:*
#         *   **Early Integration of Palliative Care:**  Begin palliative care consultations early in the disease course to address the patient's and family's physical, emotional, and spiritual needs.
#         *   **Symptom Management:**  Aggressively manage pain, nausea, constipation, and other distressing symptoms.
#         *   **Psychosocial Support:**  Provide counseling and support to the patient and family to cope with the emotional challenges of the illness.
#         *   **Advance Care Planning:**  Discuss the patient's wishes for end-of-life care and document them in an advance directive.
# *   **Emerging Therapies & Clinical Trials:**
#     *   *Rationale:*  Research is ongoing to develop disease-modifying therapies for Batten Disease.
#     *   *Action:*
#         *   **Stay Updated on Clinical Trials:**  Monitor clinicaltrials.gov and relevant patient advocacy groups (e.g., Batten Disease Support and Research Association - BDSRA) for information on ongoing clinical trials.
#         *   **Referral to Specialists:**  Refer the patient to a neurologist specializing in lysosomal storage disorders for consideration of enrollment in clinical trials or access to emerging therapies (e.g., gene therapy, enzyme replacement therapy – while there are currently no approved treatments, research is advancing).
# *   **Mental Health Support:**
#     *   *Rationale:*  Batten Disease significantly impacts patients' and families' mental health. Depression, anxiety, and grief are common.
#     *   *Action:* Refer patients and families to mental health professionals specializing in chronic illness and grief counseling. Support groups can also provide valuable emotional support.
#
# **3. How the GNN’s Predictions and SHAP Explanations Guide Clinicians:**
#
# *   **Risk Stratification & Early Detection:**
#     *   *The GNN:*  Identifies individuals at high risk of Batten Disease based on symptoms and genetic markers. This allows for earlier diagnostic testing and intervention.  If the GNN identifies a patient with "seizures" and "vision loss" along with a CLN3 mutation, the clinician is alerted to the possibility of Batten Disease and can expedite diagnostic workup.
# *   **Personalized Treatment Planning:**
#     *   *SHAP Values:*  SHAP values highlight the relative importance of different features (symptoms, mutations) in the prediction. This can help clinicians understand the individual patient's disease presentation and tailor treatment accordingly.  For example, if SHAP values indicate that seizures are the primary driver of the prediction, the clinician might prioritize aggressive seizure management. If vision loss is prominent, early intervention strategies for vision impairment should be prioritized.
# *   **Differential Diagnosis & Rule-Out:**
#     *   *The GNN:*  The model's predictions can assist in differential diagnosis by suggesting Batten Disease when other possibilities are considered.
# *   **Communication with Patients & Families:**
#     *   *SHAP Values:* Clinicians can use SHAP explanations to communicate the rationale behind the diagnosis and treatment plan to patients and families in an understandable way. This enhances trust and shared decision-making.  For example, "The model suggests Batten Disease because of the combination of seizures, vision problems, and the CLN3 mutation. The seizures are particularly important in this prediction, so controlling them will be a key part of the treatment plan."
# *   **Monitoring & Evaluation:**
#     *   *The GNN (Longitudinal Data):* By feeding longitudinal data into the model, clinicians can track the progression of the disease and adjust treatment as needed.
#
# **4. Public Health Strategies:**
#
# *   **Patient Registries:**
#     *   *Rationale:*  Registries collect data on patients with rare diseases, providing valuable information for research, treatment development, and healthcare planning.
#     *   *Action:*  Support the development and maintenance of national and international patient registries for Batten Disease. Encourage patient participation in registries.
# *   **National Screening Programs:**
#     *   *Rationale:* As mentioned earlier, if effective and cost-effective screening methods become available, consider implementing newborn or population-based screening programs, particularly in populations with a high prevalence of Batten Disease.
# *   **Public Awareness Campaigns:**
#     *   *Rationale:*  Increasing public awareness of Batten Disease can improve early diagnosis and access to care.
#     *   *Action:*  Develop and implement public awareness campaigns to educate healthcare professionals and the general public about the signs and symptoms of Batten Disease.
# *   **Research Funding:**
#     *   *Rationale:*  Continued research is essential for developing new treatments and improving the lives of patients with Batten Disease.
#     *   *Action:*  Advocate for increased funding for research on Batten Disease, including basic research, clinical trials, and translational research.
# *   **Collaboration & Networking:**
#     *   *Rationale:*  Rare disease management requires collaboration among healthcare professionals, researchers, patient advocacy groups, and policymakers.
#     *   *Action:*  Foster collaboration among these stakeholders to improve the care of patients with Batten Disease. Encourage participation in international conferences and workshops.
# *   **Access to Specialized Care Centers:**
#     *   *Rationale:* Batten Disease is a complex condition that requires specialized care.
#     *   *Action:* Ensure that patients have access to centers of excellence with expertise in Batten Disease diagnosis, treatment, and management. Telemedicine can expand access to care for patients in remote areas.
#
# **Important Considerations:**
#
# *   **Confirmation Bias:**  While the GNN provides valuable information, clinicians must avoid confirmation bias. They should critically evaluate the model's predictions and conduct thorough clinical assessments.
# *   **Data Quality:** The accuracy of the GNN's predictions depends on the quality of the data it was trained on. Efforts must be made to ensure data accuracy, completeness, and representativeness.
# *   **Ethical Considerations:**  The use of AI in healthcare raises ethical concerns, such as data privacy, algorithmic bias, and informed consent. These issues must be carefully addressed to ensure responsible use of AI.
# *   **Individualized Care:**  Every patient with Batten Disease is unique, and treatment must be individualized based on their specific needs and circumstances.
#
# By implementing these actionable steps, we can improve the early detection, management, and quality of life for patients with Batten Disease and support their families. This is a challenging but critical area of medical care. Remember to stay updated on the latest research and treatment advances.
#
#
# Responses saved to 'gemini_responses.json'

# %%
import pandas as pd
import numpy as np
import torch
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.preprocessing import LabelEncoder
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf
import json
import os
from google.colab import files
import google.generativeai as genai

# Configure Gemini API
def configure_gemini(api_key):
    try:
        genai.configure(api_key=api_key)
        return genai.GenerativeModel('gemini-1.5-flash')
    except Exception as e:
        print(f"Error configuring Gemini API: {e}")
        return None

# Get Gemini explanation
def get_gemini_explanation(model, symptoms, dna_mutations, predicted_disease):
    if model is None:
        return "Gemini API not configured."
    prompt = (
        f"'{symptoms},{dna_mutations} Based on this symptoms and dna_mutations can you what would be the most probable rare diesease' "
        f"and the predicted rare diesease Provide a one-sentence explanation for why this prediction was made."
    )
    try:
        response = model.generate_content(prompt)
        return response.text.strip()
    except Exception as e:
        print(f"Error querying Gemini API: {e}")
        return "Failed to get Gemini explanation."

# Load or create simulated dataset
def load_data(file_path='simulated_rare_disease_data.csv'):
    if os.path.exists(file_path):
        return pd.read_csv(file_path)
    else:
        print(f"{file_path} not found. Creating simulated dataset...")
        np.random.seed(42)
        data = {
            'patient_id': range(100),
            'symptoms': ['seizures,weak_legs' if i % 2 == 0 else 'rashes,fatigue' for i in range(100)],
            'dna_mutations': ['CLN3' if i % 2 == 0 else 'SNRPN' for i in range(100)],
            'disease': ['Batten Disease' if i % 2 == 0 else 'Prader-Willi Syndrome' for i in range(100)]
        }
        df = pd.DataFrame(data)
        df.to_csv(file_path, index=False)
        return df

# Preprocess data
def preprocess_data(real_data, new_patient, le_dna=None, le_disease=None):
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    bert_model = TFBertModel.from_pretrained('bert-base-uncased')

    def get_symptom_embeddings(symptoms):
        inputs = tokenizer(symptoms, return_tensors='tf', padding=True, truncation=True, max_length=50)
        outputs = bert_model(inputs)
        return outputs.pooler_output.numpy()

    real_embeddings = np.vstack([get_symptom_embeddings(s) for s in real_data['symptoms']])
    if le_dna is None:
        le_dna = LabelEncoder()
        le_dna.fit(real_data['dna_mutations'])
    real_dna = le_dna.transform(real_data['dna_mutations']).reshape(-1, 1)
    if le_disease is None:
        le_disease = LabelEncoder()
        le_disease.fit(real_data['disease'])
    real_labels = le_disease.transform(real_data['disease'])
    X_real = np.hstack([real_embeddings, real_dna])

    new_embedding = get_symptom_embeddings(new_patient['symptoms'])
    try:
        new_dna = le_dna.transform([new_patient['dna_mutations']]).reshape(-1, 1)
    except ValueError:
        print(f"Warning: DNA mutation '{new_patient['dna_mutations']}' not in training data. Using default encoding.")
        new_dna = np.zeros((1, 1))
    X_new = np.hstack([new_embedding, new_dna])

    X = np.vstack([X_real, X_new])
    y = np.concatenate([real_labels, [-1]])
    return X, y, le_dna, le_disease

# Create graph
def create_graph(X, symptoms, new_symptoms):
    edge_index = []
    all_symptoms = symptoms + [new_symptoms]
    for i in range(len(all_symptoms)):
        for j in range(i + 1, len(all_symptoms)):
            if all_symptoms[i] == all_symptoms[j]:
                edge_index.append([i, j])
                edge_index.append([j, i])
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    return Data(x=torch.tensor(X, dtype=torch.float), edge_index=edge_index)

# Define GNN model
class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return torch.log_softmax(x, dim=1)

# Predict disease
def predict_disease(new_patient, model, graph_data, le_disease):
    model.eval()
    with torch.no_grad():
        pred = model(graph_data).argmax(dim=1)
        new_patient_pred = pred[-1].item()
        try:
            predicted_disease = le_disease.inverse_transform([new_patient_pred])[0]
        except ValueError:
            predicted_disease = "Unknown Disease"
    return predicted_disease

# Generate explanation
def explain_prediction(new_patient, predicted_disease):
    return (
        f"Predicted {predicted_disease} due to symptoms: {new_patient['symptoms']} "
        f"and mutation: {new_patient['dna_mutations']}"
    )

# Main execution
if __name__ == "__main__":


    # Get Gemini API key
    api_key = 'AIzaSyDhhRDWMvhtbJWj9qgZKy79_b3pv_Co3Gg'
    gemini_model = configure_gemini(api_key)

    # Load dataset
    real_data = load_data()
    if real_data is None:
        print("Failed to load dataset. Exiting.")
        exit(1)

    # Initialize GNN model


    # Interactive input loop
    patient_records = []
    while True:
        print("\nEnter patient details (or type 'exit' to finish):")
        symptoms = input("Symptoms (e.g., rashes,fatigue): ").strip()
        if symptoms.lower() == 'exit':
            break
        dna_mutations = input("DNA Mutations (e.g., SNRPN): ").strip()
        if not symptoms or not dna_mutations:
            print("Error: Symptoms and DNA mutations are required.")
            continue

        # Create new patient
        new_patient = {
            'symptoms': symptoms,
            'dna_mutations': dna_mutations
        }

        # Preprocess
        X, y, le_dna, le_disease = preprocess_data(real_data, new_patient)

        # Create graph
        graph_data = create_graph(X, real_data['symptoms'].tolist(), new_patient['symptoms'])

        # Predict
        predicted_disease = predict_disease(new_patient, model, graph_data, le_disease)
        explanation = explain_prediction(new_patient, predicted_disease)
        gemini_explanation = get_gemini_explanation(gemini_model, symptoms, dna_mutations, predicted_disease)

        # Output

        print(f"Prediction {gemini_explanation}")

        # Record
        patient_records.append({
            'symptoms': symptoms,
            'dna_mutations': dna_mutations,
            'predicted_disease': predicted_disease,
            'explanation': explanation,
            'gemini_explanation': gemini_explanation
        })

    # Save records to JSON
    if patient_records:
        output_json = 'patient_predictions.json'
        with open(output_json, 'w') as f:
            json.dump(patient_records, f, indent=4)
        print(f"\nPredictions saved to {output_json}")
        files.download(output_json)
    else:
        print("\nNo predictions made.")
# Out:
# Enter patient details (or type 'exit' to finish):
# Symptoms (e.g., rashes,fatigue): lung tumors,stomachache,inflation in stomach
# DNA Mutations (e.g., SNRPN): cln3
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Warning: DNA mutation 'cln3' not in training data. Using default encoding.
# Prediction Based solely on the provided information (lung tumors, stomachache, stomach inflation, and CLN3 mutation), the most probable rare disease is **juvenile neuronal ceroid lipofuscinosis (JNCL)**, also known as Batten disease, because CLN3 is a gene associated with this specific type of neuronal ceroid lipofuscinosis, and while gastrointestinal symptoms aren't prominent early,  neurological issues can manifest with secondary effects impacting other body systems.
#
# Enter patient details (or type 'exit' to finish):
# Symptoms (e.g., rashes,fatigue): exit
#
# Predictions saved to patient_predictions.json

# %%
# !pip install reportlab
# Out:
# Collecting reportlab
#   Downloading reportlab-4.4.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from reportlab) (11.2.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from reportlab) (5.2.0)
# Downloading reportlab-4.4.1-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.1

# %%
import json
import os
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, PageBreak
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch

# Read Gemini responses from JSON file
def load_gemini_responses(json_file='gemini_responses.json'):
    try:
        with open(json_file, 'r') as f:
            return json.load(f)
    except FileNotFoundError:
        print(f"Error: {json_file} not found. Please run gemini_api_prompts.py first.")
        return None
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in {json_file}.")
        return None

# Generate PDF report
def generate_pdf_report(responses, output_file='rare_disease_report.pdf'):
    # Create PDF document
    doc = SimpleDocTemplate(output_file, pagesize=letter, rightMargin=inch, leftMargin=inch, topMargin=inch, bottomMargin=inch)
    styles = getSampleStyleSheet()

    # Define custom styles
    title_style = ParagraphStyle(
        name='TitleStyle',
        fontSize=16,
        leading=20,
        alignment=1,  # Center
        spaceAfter=20,
        fontName='Helvetica-Bold',
        textColor=colors.darkblue
    )
    heading_style = ParagraphStyle(
        name='HeadingStyle',
        fontSize=12,
        leading=16,
        spaceAfter=12,
        fontName='Helvetica-Bold',
        textColor=colors.black
    )
    body_style = ParagraphStyle(
        name='BodyStyle',
        fontSize=10,
        leading=14,
        spaceAfter=8,
        fontName='Helvetica',
        textColor=colors.black
    )

    # Content for the report
    content = []

    # Title
    content.append(Paragraph("Rare Disease Detection Report", title_style))
    content.append(Spacer(1, 0.2 * inch))

    # Date and Author
    content.append(Paragraph("Generated by: AI-Driven Diagnostic System", body_style))
    content.append(Paragraph("Date: May 30, 2025", body_style))
    content.append(Spacer(1, 0.3 * inch))

    # Patient Case Overview
    content.append(Paragraph("Patient Case Overview", heading_style))
    content.append(Paragraph(
        "This report details the analysis of a patient with symptoms 'seizures, weak legs' and DNA mutation 'CLN3', "
        "predicted to have Batten Disease by a Graph Neural Network (GNN) model. The model uses a dataset of patient "
        "symptoms and genetic mutations, augmented with synthetic data. Below, we explain the model's prediction, its "
        "decision-making process, and recommended steps for prevention and control, based on insights from Google Gemini AI.",
        body_style
    ))
    content.append(Spacer(1, 0.2 * inch))

    # Why the Model Predicted Batten Disease
    content.append(Paragraph("Why the Model Predicted Batten Disease", heading_style))
    why_text = responses.get('why_prediction', 'No response available.')
    content.append(Paragraph(why_text.replace('\n', '<br/>'), body_style))
    content.append(Spacer(1, 0.2 * inch))

    # How the Model Arrived at the Prediction
    content.append(Paragraph("How the Model Arrived at the Prediction", heading_style))
    how_text = responses.get('how_prediction', 'No response available.')
    content.append(Paragraph(how_text.replace('\n', '<br/>'), body_style))
    content.append(Spacer(1, 0.2 * inch))

    # Next Steps for Prevention and Control
    content.append(Paragraph("Next Steps for Prevention and Control", heading_style))
    prevention_text = responses.get('prevention_control', 'No response available.')
    content.append(Paragraph(prevention_text.replace('\n', '<br/>'), body_style))
    content.append(Spacer(1, 0.2 * inch))

    # Conclusion
    content.append(Paragraph("Conclusion", heading_style))
    content.append(Paragraph(
        "The GNN model provides a robust prediction of Batten Disease for the patient based on symptoms and genetic data. "
        "The explanations highlight key features (e.g., seizures, CLN3 mutation) driving the prediction, while prevention "
        "and control measures offer actionable guidance for clinicians. For further details, contact the AI diagnostic team.",
        body_style
    ))

    # Build the PDF
    doc.build(content)
    print(f"PDF generated: {output_file}")

# Main execution
if __name__ == "__main__":
    # Load Gemini responses
    responses = load_gemini_responses()
    if responses is None:
        exit(1)

    # Generate PDF report
    generate_pdf_report(responses)
# Out:
# PDF generated: rare_disease_report.pdf
